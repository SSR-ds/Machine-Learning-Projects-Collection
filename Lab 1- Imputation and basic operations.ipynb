# %%
import pandas as pd
import numpy as np

# %%
df1  = pd.read_csv("adult.csv")

# %%
df1.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df1.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# Salary            object
# dtype: object

# %%
df1.replace({' ?':None}, inplace = True)

# %%
df1.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# Salary               0
# dtype: int64

# %%
df1.replace('^\s+', '', regex=True, inplace=True) #front
df1.replace('\s+$', '', regex=True, inplace=True) #back

# %%
abc = df1.loc[(df1['Salary'] == '<=50K') & (df1['native-country'] == 'United-States')]

# %%
abc.count()
# Out:
# age               21999
# workclass         20516
# fnlwgt            21999
# education         21999
# education-num     21999
# marital-status    21999
# occupation        20509
# relationship      21999
# race              21999
# sex               21999
# capital-gain      21999
# capital-loss      21999
# hours-per-week    21999
# native-country    21999
# Salary            21999
# dtype: int64

# %%
mas =df1.loc[(df1['Salary'] == '>50K') & (df1['native-country'] == 'United-States')]

# %%
mas.count()
# Out:
# age               7171
# workclass         6995
# fnlwgt            7171
# education         7171
# education-num     7171
# marital-status    7171
# occupation        6995
# relationship      7171
# race              7171
# sex               7171
# capital-gain      7171
# capital-loss      7171
# hours-per-week    7171
# native-country    7171
# Salary            7171
# dtype: int64

# %%
mt = df1.groupby(['native-country','Salary']).count()
pd.set_option('display.max_rows', df1.shape[0]+1)
print(mt)
# Out:
#                                      age  workclass  fnlwgt  education  \
# native-country             Salary
# Cambodia                   <=50K      12         11      12         12
#                            >50K        7          7       7          7
# Canada                     <=50K      82         71      82         82
#                            >50K       39         36      39         39
# China                      <=50K      55         48      55         55
#                            >50K       20         20      20         20
# Columbia                   <=50K      57         54      57         57
#                            >50K        2          2       2          2
# Cuba                       <=50K      70         67      70         70
#                            >50K       25         25      25         25
# Dominican-Republic         <=50K      68         65      68         68
#                            >50K        2          2       2          2
# ...

# %%
df2 = pd.read_csv("auto.csv")

# %%
df2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  15.0          8         350.0        165    3693          11.5          70
# 1  18.0          8         318.0        150    3436          11.0          70
# 2  16.0          8         304.0        150    3433          12.0          70
# 3  17.0          8         302.0        140    3449          10.5          70
# 4  15.0          8         429.0        198    4341          10.0          70
#
#    origin            car name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500

# %%
df2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df2.replace({'?':None}, inplace = True)

# %%
df2['horsepower'] = df2['horsepower'].astype(float)

# %%
df2.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
grouped = df2.groupby(['cylinders']).agg({'horsepower' : 'mean'})

# %%
grouped
# Out:
#            horsepower
# cylinders
# 3           99.250000
# 4           78.281407
# 5           82.333333
# 6          101.506024
# 8          158.578431

# %%
df_4 = df2[df2['cylinders'] == 4]

# %%
df_4['horsepower'].mean()
# Out:
# 78.28140703517587

# %%
df_6 = df2[df2['cylinders'] == 6]

# %%
df_6['horsepower'].mean()
# Out:
# 101.50602409638554
